# %% [markdown]
# # TEEHR Evaluation Example 3
# ## Hourly NWM Retrospective 3.0, CAMELS Subset (648)

# %% [markdown]
# ### 1. Get the data from S3
# For the sake of time, we prepared the individual datasets in advance and are simply copying to your 2i2c home directory. After running the cell below to copy the example_2 data.

# %%
# !rm -rf ~/teehr/example-3/*
# !aws s3 cp --recursive --no-sign-request s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3 ~/teehr/example-3
# Out:
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_aridity.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_aridity.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_dom_land_cover.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_dom_land_cover.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_dom_land_cover_frac.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_dom_land_cover_frac.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_forest_frac.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_forest_frac.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_high_prec_freq.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_high_prec_freq.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_p_mean.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_p_mean.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_pet_mean.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_pet_mean.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_frac_snow.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_frac_snow.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_drainage_area.all.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_drainage_area.all.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_slope_mean.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_slope_mean.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_p_seasonality.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_p_seasonality.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_soil_porosity.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_soil_porosity.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_q5.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_q5.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_frac_urban.conus.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_frac_urban.conus.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_q95.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_q95.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_rfc.conus.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_rfc.conus.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_runoff_ratio.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_runoff_ratio.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_basin_attr_elev_mean.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_basin_attr_elev_mean.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_q_mean.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_q_mean.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_high_q_freq.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_high_q_freq.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_stream_order.conus.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_stream_order.conus.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_slope_fdc.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_slope_fdc.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_baseflow_index.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_baseflow_index.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_dist_to_dam_nid.conus.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_dist_to_dam_nid.conus.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_zero_q_freq.camels.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_zero_q_freq.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/crosswalks/usgs_nwm30_crosswalk.camels.parquet to ../../home/jovyan/teehr/example-3/crosswalks/usgs_nwm30_crosswalk.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/attributes/usgs_point_attr_ecoregions.conus.parquet to ../../home/jovyan/teehr/example-3/attributes/usgs_point_attr_ecoregions.conus.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/geometry/usgs_point_geometry.camels.parquet to ../../home/jovyan/teehr/example-3/geometry/usgs_point_geometry.camels.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1981.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1981.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1982.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1982.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1984.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1984.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1983.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1983.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1985.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1985.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1986.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1986.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1987.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1987.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1988.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1988.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1989.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1989.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1990.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1990.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1991.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1991.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1992.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1992.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1993.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1993.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1998.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1998.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1995.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1995.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1996.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1996.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1997.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1997.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1994.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1994.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2001.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2001.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2003.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2003.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2000.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2000.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1999.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_1999.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2002.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2002.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2005.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2005.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2007.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2007.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2008.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2008.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2010.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2010.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2009.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2009.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2006.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2006.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2004.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2004.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2013.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2013.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2014.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2014.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2011.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2011.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2016.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2016.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2012.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2012.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2015.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2015.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2017.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2017.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2018.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2018.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2020.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2020.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2022.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2022.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2019.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2019.parquet
# download: s3://ciroh-rti-public-data/teehr-workshop-devcon-2024/workshop-data/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2021.parquet to ../../home/jovyan/teehr/example-3/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/nwm30_retro_2021.parquet

# %%
# !tree ~/teehr/example-3/
# Out:
# /home/jovyan/teehr/example-3/
# ├── attributes
# │   ├── usgs_basin_attr_aridity.camels.parquet
# │   ├── usgs_basin_attr_dom_land_cover.camels.parquet
# │   ├── usgs_basin_attr_dom_land_cover_frac.camels.parquet
# │   ├── usgs_basin_attr_drainage_area.all.parquet
# │   ├── usgs_basin_attr_elev_mean.camels.parquet
# │   ├── usgs_basin_attr_forest_frac.camels.parquet
# │   ├── usgs_basin_attr_frac_snow.camels.parquet
# │   ├── usgs_basin_attr_frac_urban.conus.parquet
# │   ├── usgs_basin_attr_high_prec_freq.camels.parquet
# │   ├── usgs_basin_attr_p_mean.camels.parquet
# │   ├── usgs_basin_attr_p_seasonality.camels.parquet
# │   ├── usgs_basin_attr_pet_mean.camels.parquet
# │   ├── usgs_basin_attr_slope_mean.camels.parquet
# │   ├── usgs_basin_attr_soil_porosity.camels.parquet
# │   ├── usgs_point_attr_baseflow_index.camels.parquet
# │   ├── usgs_point_attr_dist_to_dam_nid.conus.parquet
# │   ├── usgs_point_attr_ecoregions.conus.parquet
# │   ├── usgs_point_attr_high_q_freq.camels.parquet
# │   ├── usgs_point_attr_q5.camels.parquet
# │   ├── usgs_point_attr_q95.camels.parquet
# │   ├── usgs_point_attr_q_mean.camels.parquet
# │   ├── usgs_point_attr_rfc.conus.parquet
# │   ├── usgs_point_attr_runoff_ratio.camels.parquet
# │   ├── usgs_point_attr_slope_fdc.camels.parquet
# │   ├── usgs_point_attr_stream_order.conus.parquet
# │   └── usgs_point_attr_zero_q_freq.camels.parquet
# ├── crosswalks
# │   └── usgs_nwm30_crosswalk.camels.parquet
# ├── geometry
# │   └── usgs_point_geometry.camels.parquet
# └── joined
#     └── configuration=nwm30_retro
#         └── variable_name=streamflow_hourly_inst
#             ├── nwm30_retro_1981.parquet
#             ├── nwm30_retro_1982.parquet
#             ├── nwm30_retro_1983.parquet
#             ├── nwm30_retro_1984.parquet
#             ├── nwm30_retro_1985.parquet
#             ├── nwm30_retro_1986.parquet
#             ├── nwm30_retro_1987.parquet
#             ├── nwm30_retro_1988.parquet
#             ├── nwm30_retro_1989.parquet
#             ├── nwm30_retro_1990.parquet
#             ├── nwm30_retro_1991.parquet
#             ├── nwm30_retro_1992.parquet
#             ├── nwm30_retro_1993.parquet
#             ├── nwm30_retro_1994.parquet
#             ├── nwm30_retro_1995.parquet
#             ├── nwm30_retro_1996.parquet
#             ├── nwm30_retro_1997.parquet
#             ├── nwm30_retro_1998.parquet
#             ├── nwm30_retro_1999.parquet
#             ├── nwm30_retro_2000.parquet
#             ├── nwm30_retro_2001.parquet
#             ├── nwm30_retro_2002.parquet
#             ├── nwm30_retro_2003.parquet
#             ├── nwm30_retro_2004.parquet
#             ├── nwm30_retro_2005.parquet
#             ├── nwm30_retro_2006.parquet
#             ├── nwm30_retro_2007.parquet
#             ├── nwm30_retro_2008.parquet
#             ├── nwm30_retro_2009.parquet
#             ├── nwm30_retro_2010.parquet
#             ├── nwm30_retro_2011.parquet
#             ├── nwm30_retro_2012.parquet
#             ├── nwm30_retro_2013.parquet
#             ├── nwm30_retro_2014.parquet
#             ├── nwm30_retro_2015.parquet
#             ├── nwm30_retro_2016.parquet
#             ├── nwm30_retro_2017.parquet
#             ├── nwm30_retro_2018.parquet
#             ├── nwm30_retro_2019.parquet
#             ├── nwm30_retro_2020.parquet
#             ├── nwm30_retro_2021.parquet
#             └── nwm30_retro_2022.parquet
#
# 6 directories, 70 files

# %% [markdown]
# ### Evaluate Model Output
# This notebook we will demonstrate how to use TEEHR to calculate metrics from a previously created joined TEEHR database containing hourly NWM3.0 Retrospective simulations and USGS observations from 1981-2022, using a range of different options for grouping and filtering.  We will then create some common graphics based on the results (the same as Example 2)
#
#
# #### In this notebook we will perform the following steps:
# <ol>
#     <li> Review the contents of our joined parquet file </li>
#     <li> Calculate metrics with different group_by options </li>
#     <li> Calculate metrics with different filters options </li>
#     <li> Example visualizations of TEEHR results</li>
# </ol>
#
# #### First setup the TEEHR class and review the contents of the joined parquet file

# %%
from teehr.classes.duckdb_joined_parquet import DuckDBJoinedParquet
from pathlib import Path

# Define the paths to the joined parquet file and the geometry files
TEEHR_BASE = Path(Path.home(), 'teehr/example-3')
JOINED_PARQUET_FILEPATH = f"{TEEHR_BASE}/joined/configuration=nwm30_retro/variable_name=streamflow_hourly_inst/*.parquet"
GEOMETRY_FILEPATH = f"{TEEHR_BASE}/geometry/**/*.parquet"

# Initialize a teehr joined parquet class with our parquet file and geometry
joined_data = DuckDBJoinedParquet(
    joined_parquet_filepath = JOINED_PARQUET_FILEPATH,
    geometry_filepath = GEOMETRY_FILEPATH
)

# %% [markdown]
# ### 1. Review the contents of the joined parquet files
#
# In practice, you may want to review the fields of data in the parquet file to plan your evaluation strategy.  If the dataset is large, reading it into a dataframe may be cumbersome or even infeasible in some cases. TEEHR provides the ```get_joined_timeseries_schema``` method to quickly review the fields of the joined parquet file and the ```get_unique_field_values``` method to review the unique values contained in a specified field.  The latter is particularly helpful for building dashboards for evaluation (e.g., to populate a drop down menu of possible filter or group_by values).

# %%
# Remind ourselves what fields were included
joined_data.get_joined_timeseries_schema()
# Out:
#                         column_name column_type null   key default extra
# 0                    reference_time   TIMESTAMP  YES  None    None  None
# 1                        value_time   TIMESTAMP  YES  None    None  None
# 2             secondary_location_id     VARCHAR  YES  None    None  None
# 3                   secondary_value       FLOAT  YES  None    None  None
# 4                     configuration     VARCHAR  YES  None    None  None
# 5                  measurement_unit     VARCHAR  YES  None    None  None
# 6                     variable_name     VARCHAR  YES  None    None  None
# 7                     primary_value       FLOAT  YES  None    None  None
# 8               primary_location_id     VARCHAR  YES  None    None  None
# 9                      aridity_none     VARCHAR  YES  None    None  None
# 10                  frac_urban_none     VARCHAR  YES  None    None  None
# 11         high_prec_freq_days_year     VARCHAR  YES  None    None  None
# 12                       q_mean_cms     VARCHAR  YES  None    None  None
# 13                 forest_frac_none     VARCHAR  YES  None    None  None
# 14                ecoregion_L2_none     VARCHAR  YES  None    None  None
# 15              zero_q_freq_percent     VARCHAR  YES  None    None  None
# 16            high_q_freq_days_year     VARCHAR  YES  None    None  None
# 17                   frac_snow_none     VARCHAR  YES  None    None  None
# 18                    p_mean_mm_day     VARCHAR  YES  None    None  None
# 19                   slope_fdc_none     VARCHAR  YES  None    None  None
# 20              dom_land_cover_none     VARCHAR  YES  None    None  None
# 21  elev_mean_meter_above_sea_level     VARCHAR  YES  None    None  None
# 22                          q95_cms     VARCHAR  YES  None    None  None
# 23                drainage_area_km2     VARCHAR  YES  None    None  None
# 24                upstream_area_km2     VARCHAR  YES  None    None  None
# 25         dom_land_cover_frac_none     VARCHAR  YES  None    None  None
# 26              baseflow_index_none     VARCHAR  YES  None    None  None
# 27                stream_order_none     VARCHAR  YES  None    None  None
# 28               soil_porosity_none     VARCHAR  YES  None    None  None
# 29       river_forecast_center_none     VARCHAR  YES  None    None  None
# 30               p_seasonality_none     VARCHAR  YES  None    None  None
# 31                runoff_ratio_none     VARCHAR  YES  None    None  None
# 32                           q5_cms     VARCHAR  YES  None    None  None
# 33                  slope_mean_m_km     VARCHAR  YES  None    None  None
# 34                  pet_mean_mm_day     VARCHAR  YES  None    None  None
# 35                NID_dam_lengths_m     VARCHAR  YES  None    None  None
# 36                            month     INTEGER  YES  None    None  None
# 37         obs_flow_category_q_mean     VARCHAR  YES  None    None  None
# 38               obs_above_below_q5     VARCHAR  YES  None    None  None
# 39              obs_above_below_q95     VARCHAR  YES  None    None  None
# 40         sim_flow_category_q_mean     VARCHAR  YES  None    None  None
# 41               sim_above_below_q5     VARCHAR  YES  None    None  None
# 42              sim_above_below_q95     VARCHAR  YES  None    None  None

# %%
# Review what configuration datasets were included
joined_data.get_unique_field_values('configuration')
# Out:
#   unique_configuration_values
# 0                 nwm30_retro

# %%
# ...number of locations
len(joined_data.get_unique_field_values('primary_location_id'))
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# 647

# %% [markdown]
# ### 2. Calculate metrics

# %%
# %%time

gdf_all = joined_data.get_metrics(
    group_by=["primary_location_id", "configuration"],
    order_by=["primary_location_id", "configuration"],
    include_metrics=[
        'kling_gupta_efficiency_mod2',
        'relative_bias',
        'pearson_correlation',                  
        'nash_sutcliffe_efficiency_normalized',  
        'mean_absolute_relative_error',
        'primary_count' 
    ],
    include_geometry=True,
)
# view the dataframe
gdf_all
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 1min 11s, sys: 475 ms, total: 1min 11s
# Wall time: 18.5 s
#     primary_location_id configuration  kling_gupta_efficiency_mod2  \
# 0         usgs-01013500   nwm30_retro                     0.391628
# 1         usgs-01022500   nwm30_retro                     0.680773
# 2         usgs-01030500   nwm30_retro                     0.709208
# 3         usgs-01031500   nwm30_retro                     0.768625
# 4         usgs-01047000   nwm30_retro                     0.679907
# ..                  ...           ...                          ...
# 642       usgs-14309500   nwm30_retro                     0.831301
# 643       usgs-14316700   nwm30_retro                     0.797103
# 644       usgs-14325000   nwm30_retro                     0.734790
# 645       usgs-14362250   nwm30_retro                     0.507605
# 646       usgs-14400000   nwm30_retro                     0.822070
#
#      relative_bias  pearson_correlation  nash_sutcliffe_efficiency_normalized  \
# 0        -0.041872             0.802823                              0.667056
# 1        -0.177140             0.838066                              0.754479
# 2        -0.203271             0.829589                              0.746575
# 3        -0.041667             0.783091                              0.678686
# 4         0.070001             0.744362                              0.608151
# ..             ...                  ...                                   ...
# 642      -0.008467             0.834059                              0.744712
# 643      -0.014002             0.836359                              0.724203
# 644       0.009141             0.849341                              0.706860
# 645      -0.084728             0.509288                              0.497379
# 646      -0.173737             0.862135                              0.767905
#
#      mean_absolute_relative_error  primary_count                     geometry
# 0                        0.499498         195876   POINT (-68.58278 47.23750)
# 1                        0.341755         223852   POINT (-67.93528 44.60806)
# 2                        0.402818         194840   POINT (-68.30583 45.50111)
# 3                        0.491308         195481   POINT (-69.31472 45.17500)
# 4                        0.507747         195651   POINT (-69.95500 44.86917)
# ..                            ...            ...                          ...
# 642                      0.464768         280477  POINT (-123.61091 42.80400)
# 643                      0.431458         284668  POINT (-122.72894 43.34984)
# 644                      0.501058         261938  POINT (-124.07065 42.89150)
# 645                      0.959275         271371  POINT (-123.07532 42.15401)
# 646                      0.444557         262992  POINT (-124.18731 42.12344)
#
# [647 rows x 9 columns]

# %%
# use pandas magic to create a nice summary table of the metrics by model configuration across locations
gdf_all.groupby('configuration').describe(percentiles=[.5]).unstack(1).reset_index().rename(
    columns={'level_0':'metric','level_1':'summary'}).pivot(
    index=['metric','configuration'], values=0, columns='summary')
# Out:
# summary                                                       50%  count  \
# metric                               configuration
# kling_gupta_efficiency_mod2          nwm30_retro         0.675088  647.0
# mean_absolute_relative_error         nwm30_retro         0.535176  647.0
# nash_sutcliffe_efficiency_normalized nwm30_retro         0.667654  647.0
# pearson_correlation                  nwm30_retro         0.765011  647.0
# primary_count                        nwm30_retro    251039.000000  647.0
# relative_bias                        nwm30_retro        -0.049238  647.0
#
# summary                                                       max  \
# metric                               configuration
# kling_gupta_efficiency_mod2          nwm30_retro         0.915274
# mean_absolute_relative_error         nwm30_retro         4.505550
# nash_sutcliffe_efficiency_normalized nwm30_retro         0.875057
# pearson_correlation                  nwm30_retro         0.940297
# primary_count                        nwm30_retro    335997.000000
# relative_bias                        nwm30_retro         3.881756
#
# summary                                                      mean  \
# metric                               configuration
# kling_gupta_efficiency_mod2          nwm30_retro         0.574126
# mean_absolute_relative_error         nwm30_retro         0.615383
# nash_sutcliffe_efficiency_normalized nwm30_retro         0.637685
# pearson_correlation                  nwm30_retro         0.721231
# primary_count                        nwm30_retro    243504.554869
# relative_bias                        nwm30_retro        -0.020543
#
# summary                                                       min  \
# metric                               configuration
# kling_gupta_efficiency_mod2          nwm30_retro        -2.844150
# mean_absolute_relative_error         nwm30_retro         0.246365
# nash_sutcliffe_efficiency_normalized nwm30_retro         0.047997
# pearson_correlation                  nwm30_retro         0.056232
# primary_count                        nwm30_retro    113410.000000
# relative_bias                        nwm30_retro        -0.879751
#
# summary                                                      std
# metric                               configuration
# kling_gupta_efficiency_mod2          nwm30_retro        0.368454
# mean_absolute_relative_error         nwm30_retro        0.353796
# nash_sutcliffe_efficiency_normalized nwm30_retro        0.136910
# pearson_correlation                  nwm30_retro        0.146400
# primary_count                        nwm30_retro    44774.729843
# relative_bias                        nwm30_retro        0.378886

# %%
# %%time

'''
Calculate metrics separately for low flows and high flows based on the 
calculated field "obs_flow_category_q_mean" -> add the field to the group_by list.  
'''

gdf_flowcat = joined_data.get_metrics(
    group_by=["primary_location_id", "configuration", "obs_flow_category_q_mean"],
    order_by=["primary_location_id", "configuration"],
    include_metrics=[
        'kling_gupta_efficiency_mod2',
        'pearson_correlation',                  
        'mean_absolute_relative_error',
        'primary_count' 
    ],
)
display(gdf_flowcat)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#      primary_location_id configuration obs_flow_category_q_mean  \
# 0          usgs-01013500   nwm30_retro                     high
# 1          usgs-01013500   nwm30_retro                      low
# 2          usgs-01022500   nwm30_retro                     high
# 3          usgs-01022500   nwm30_retro                      low
# 4          usgs-01030500   nwm30_retro                     high
# ...                  ...           ...                      ...
# 1289       usgs-14325000   nwm30_retro                     high
# 1290       usgs-14362250   nwm30_retro                     high
# 1291       usgs-14362250   nwm30_retro                      low
# 1292       usgs-14400000   nwm30_retro                      low
# 1293       usgs-14400000   nwm30_retro                     high
#
#       kling_gupta_efficiency_mod2  pearson_correlation  \
# 0                        0.148342             0.660219
# 1                       -0.566669             0.677014
# 2                        0.481649             0.701277
# 3                        0.685788             0.747815
# 4                        0.481961             0.707217
# ...                           ...                  ...
# 1289                     0.618714             0.803206
# 1290                     0.378903             0.426588
# 1291                    -0.534671             0.397176
# 1292                     0.502249             0.608719
# 1293                     0.647998             0.815627
#
#       mean_absolute_relative_error  primary_count
# 0                         0.379313          76712
# 1                         0.901567         119164
# 2                         0.342938          82032
# 3                         0.337945         141820
# 4                         0.385183          75022
# ...                            ...            ...
# 1289                      0.455834          76474
# 1290                      0.853640          52324
# 1291                      1.320719         219047
# 1292                      0.519422         190160
# 1293                      0.425629          72832
#
# [1294 rows x 7 columns]
# CPU times: user 33.9 s, sys: 348 ms, total: 34.2 s
# Wall time: 8.72 s

# %%
gdf_flowcat.groupby(['obs_flow_category_q_mean']).describe(percentiles=[.5]).unstack().reset_index().rename(
    columns={'level_0':'metric','level_1':'summary'}).pivot(
    index=['metric','obs_flow_category_q_mean'], values=0, columns='summary')
# Out:
# summary                                                          50%  count  \
# metric                       obs_flow_category_q_mean
# kling_gupta_efficiency_mod2  high                           0.580969  647.0
#                              low                           -0.103700  647.0
# mean_absolute_relative_error high                           0.494366  647.0
#                              low                            0.654675  647.0
# pearson_correlation          high                           0.698067  647.0
#                              low                            0.543568  647.0
# primary_count                high                       64873.000000  647.0
#                              low                       182760.000000  647.0
#
# summary                                                          max  \
# metric                       obs_flow_category_q_mean
# kling_gupta_efficiency_mod2  high                           0.907899
#                              low                            0.853502
# mean_absolute_relative_error high                           3.175267
#                              low                          192.423554
# pearson_correlation          high                           0.913775
#                              low                            0.876188
# primary_count                high                      156080.000000
#                              low                       272679.000000
#
# summary                                                         mean  \
# metric                       obs_flow_category_q_mean
# kling_gupta_efficiency_mod2  high                           0.459290
#                              low                           -1.606504
# mean_absolute_relative_error high                           0.555114
#                              low                            1.285105
# pearson_correlation          high                           0.650666
#                              low                            0.515055
# primary_count                high                       63031.854714
#                              low                       180472.700155
#
# summary                                                         min  \
# metric                       obs_flow_category_q_mean
# kling_gupta_efficiency_mod2  high                         -4.363031
#                              low                        -151.827130
# mean_absolute_relative_error high                          0.225015
#                              low                           0.209537
# pearson_correlation          high                         -0.020598
#                              low                           0.017918
# primary_count                high                       1989.000000
#                              low                       67836.000000
#
# summary                                                         std
# metric                       obs_flow_category_q_mean
# kling_gupta_efficiency_mod2  high                          0.442827
#                              low                           8.014236
# mean_absolute_relative_error high                          0.264109
#                              low                           7.658334
# pearson_correlation          high                          0.159303
#                              low                           0.177805
# primary_count                high                      24644.963086
#                              low                       40173.639835

# %%
# %%time
'''
Now add the location characteristics you want included in the metrics table
(for output tables and visualization)

To include location-specific attributes in the metrics table, those attributes 
must be added to the group_by list.  If grouping across locations (.e.g., all locations 
within an RFC region), you should only add attributes that area already aggregated by that 
same region (TEEHR does not check for this). An example of including location characteristic 
attributes is included below. </li>

'''
# list the attributes that are location characteristics that you want to include 
# in the metrics results tables
# in the metrics results tables
include_location_characteristics = [
    'aridity_none',
    'runoff_ratio_none',
    'baseflow_index_none',
    'stream_order_none',  
    'q_mean_cms',
    'slope_fdc_none',  
    'frac_urban_none',
    'frac_snow_none',
    'forest_frac_none',
    'ecoregion_L2_none',
    'river_forecast_center_none',
]
df_atts = joined_data.get_metrics(
    group_by=["primary_location_id", "configuration"] + include_location_characteristics,
    order_by=["primary_location_id", "configuration"],
    include_metrics=[
        'kling_gupta_efficiency_mod2',
        'pearson_correlation',                  
        'mean_absolute_relative_error',
        'relative_bias',
        'primary_count' 
    ],
    include_geometry=False,
)

# view the dataframe
display(df_atts)

# summarize just the median results across locations by attribute (river forecast center)
df_atts_summary = df_atts.groupby(['configuration','river_forecast_center_none'])\
    .describe(percentiles=[.5]).unstack().unstack().reset_index()\
    .rename(columns={'level_0':'metric','level_1':'summary'})
df_atts_summary[df_atts_summary['summary'].isin(['50%'])].pivot(
    index=['river_forecast_center_none','configuration'],values=0, columns=['metric','summary'])
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
#     primary_location_id configuration       aridity_none  runoff_ratio_none  \
# 0         usgs-01013500   nwm30_retro   0.63055865946247  0.543437466590222
# 1         usgs-01022500   nwm30_retro  0.587356423405076  0.602268929482991
# 2         usgs-01030500   nwm30_retro  0.624111385131731  0.555858982560286
# 3         usgs-01031500   nwm30_retro  0.587950340389816  0.576289279160751
# 4         usgs-01047000   nwm30_retro  0.628929335570973   0.65686843497944
# ..                  ...           ...                ...                ...
# 642       usgs-14309500   nwm30_retro  0.627228059860258  0.493734021695294
# 643       usgs-14316700   nwm30_retro  0.501305088892464  0.643997143591881
# 644       usgs-14325000   nwm30_retro   0.38660991574857   0.64665721307564
# 645       usgs-14362250   nwm30_retro   1.19539041561722  0.119357982098672
# 646       usgs-14400000   nwm30_retro  0.410302083666978   1.36213210945676
#
#     baseflow_index_none stream_order_none           q_mean_cms  \
# 0     0.585225955779508                 5   44.467109455834866
# 1     0.554478447930409                 5   14.786380055715862
# 2     0.508440712580478                 5    77.36721025688733
# 3     0.445090526012048                 5    18.13589110971241
# 4     0.473464930849723                 4    23.09950986229729
# ..                  ...               ...                  ...
# 642   0.459454969190781                 3     6.40310450370619
# 643   0.508616082222394                 5   19.909239533259516
# 644   0.480768555174975                 4   20.630074080228493
# 645   0.518407661642124                 2  0.15909060816317996
# 646   0.485781099460213                 4    61.48207719040457
#
#        slope_fdc_none        frac_urban_none      frac_snow_none  \
# 0    1.52821853538976                   0.01   0.313440357191799
# 1    1.77627980351081                 0.0092   0.245259009248271
# 2    1.87111040605632                 0.0067    0.27701840295357
# 3    1.49401920331253                 0.0123   0.291836473001958
# 4    1.41593871068099   0.012199999999999999   0.280118126940736
# ..                ...                    ...                 ...
# 642  1.68988956221131                 0.0025  0.0612553691709827
# 643  2.23102329485064                    0.0   0.176336580742005
# 644  2.24613455803779  0.0040999999999999995  0.0302033920558714
# 645  1.18603999268406                 0.0018   0.141500009350329
# 646  2.01743476763189  0.0014000000000000002  0.0243303906906382
#
#     forest_frac_none              ecoregion_L2_none  \
# 0             0.9063         8.1  MIXED WOOD PLAINS
# 1             0.9232         8.1  MIXED WOOD PLAINS
# 2             0.8782         8.1  MIXED WOOD PLAINS
# 3             0.9548         8.1  MIXED WOOD PLAINS
# 4             0.9906         8.1  MIXED WOOD PLAINS
# ..               ...                            ...
# 642              1.0        6.2  WESTERN CORDILLERA
# 643              1.0        6.2  WESTERN CORDILLERA
# 644              1.0  7.1  MARINE WEST COAST FOREST
# 645              1.0        6.2  WESTERN CORDILLERA
# 646              1.0  7.1  MARINE WEST COAST FOREST
#
#     river_forecast_center_none  kling_gupta_efficiency_mod2  \
# 0                        NERFC                     0.391628
# 1                        NERFC                     0.680773
# 2                        NERFC                     0.709208
# 3                        NERFC                     0.768625
# 4                        NERFC                     0.679907
# ..                         ...                          ...
# 642                      NWRFC                     0.831301
# 643                      NWRFC                     0.797103
# 644                      NWRFC                     0.734790
# 645                      NWRFC                     0.507605
# 646                      NWRFC                     0.822070
#
#      pearson_correlation  mean_absolute_relative_error  relative_bias  \
# 0               0.802823                      0.499498      -0.041872
# 1               0.838066                      0.341755      -0.177140
# 2               0.829589                      0.402818      -0.203271
# 3               0.783091                      0.491308      -0.041667
# 4               0.744362                      0.507747       0.070001
# ..                   ...                           ...            ...
# 642             0.834059                      0.464768      -0.008467
# 643             0.836359                      0.431458      -0.014002
# 644             0.849341                      0.501058       0.009141
# 645             0.509288                      0.959275      -0.084728
# 646             0.862135                      0.444557      -0.173737
#
#      primary_count
# 0           195876
# 1           223852
# 2           194840
# 3           195481
# 4           195651
# ..             ...
# 642         280477
# 643         284668
# 644         261938
# 645         271371
# 646         262992
#
# [647 rows x 18 columns]
# CPU times: user 1min 39s, sys: 612 ms, total: 1min 39s
# Wall time: 25.3 s
# metric                                   kling_gupta_efficiency_mod2  \
# summary                                                          50%
# river_forecast_center_none configuration
# ABRFC                      nwm30_retro                      0.646766
# CBRFC                      nwm30_retro                      0.504790
# CNRFC                      nwm30_retro                      0.600172
# LMRFC                      nwm30_retro                      0.761364
# MARFC                      nwm30_retro                      0.667934
# MBRFC                      nwm30_retro                      0.552780
# NCRFC                      nwm30_retro                      0.632238
# NERFC                      nwm30_retro                      0.657678
# NWRFC                      nwm30_retro                      0.796064
# OHRFC                      nwm30_retro                      0.731760
# SERFC                      nwm30_retro                      0.686403
# WGRFC                      nwm30_retro                      0.486497
#
# metric                                   pearson_correlation  \
# summary                                                  50%
# river_forecast_center_none configuration
# ABRFC                      nwm30_retro              0.743724
# CBRFC                      nwm30_retro              0.702087
# CNRFC                      nwm30_retro              0.728902
# LMRFC                      nwm30_retro              0.817299
# MARFC                      nwm30_retro              0.760434
# MBRFC                      nwm30_retro              0.723873
# NCRFC                      nwm30_retro              0.730732
# NERFC                      nwm30_retro              0.755718
# NWRFC                      nwm30_retro              0.846393
# OHRFC                      nwm30_retro              0.770886
# SERFC                      nwm30_retro              0.750800
# WGRFC                      nwm30_retro              0.632754
#
# metric                                   mean_absolute_relative_error  \
# summary                                                           50%
# river_forecast_center_none configuration
# ABRFC                      nwm30_retro                       0.648113
# CBRFC                      nwm30_retro                       0.749092
# CNRFC                      nwm30_retro                       0.623043
# LMRFC                      nwm30_retro                       0.460484
# MARFC                      nwm30_retro                       0.447674
# MBRFC                      nwm30_retro                       0.692621
# NCRFC                      nwm30_retro                       0.579652
# NERFC                      nwm30_retro                       0.507559
# NWRFC                      nwm30_retro                       0.371724
# OHRFC                      nwm30_retro                       0.495271
# SERFC                      nwm30_retro                       0.525364
# WGRFC                      nwm30_retro                       0.825003
#
# metric                                   relative_bias primary_count
# summary                                            50%           50%
# river_forecast_center_none configuration
# ABRFC                      nwm30_retro       -0.090962      252850.0
# CBRFC                      nwm30_retro        0.151870      243805.5
# CNRFC                      nwm30_retro        0.082032      279315.0
# LMRFC                      nwm30_retro       -0.041267      269302.0
# MARFC                      nwm30_retro       -0.053741      248907.0
# MBRFC                      nwm30_retro       -0.267085      207622.0
# NCRFC                      nwm30_retro       -0.164602      224216.5
# NERFC                      nwm30_retro        0.046480      226378.0
# NWRFC                      nwm30_retro        0.006148      280477.0
# OHRFC                      nwm30_retro       -0.048039      248212.0
# SERFC                      nwm30_retro       -0.127146      269067.5
# WGRFC                      nwm30_retro       -0.186187      252172.0

# %%
# %%time

import geoviews as gv
import holoviews as hv
import colorcet as cc
hv.extension('bokeh', logo=False)
gv.extension('bokeh', logo=False)
basemap = hv.element.tiles.CartoLight()

gdf_filters = joined_data.get_metrics(
    group_by=["primary_location_id", "configuration", "stream_order_none"],
    order_by=["primary_location_id", "configuration"],
    include_metrics=[
        'kling_gupta_efficiency_mod2',
        'relative_bias',
        'pearson_correlation',                  
        'nash_sutcliffe_efficiency_normalized',  
        'mean_absolute_relative_error',
        'primary_count' 
    ],
    filters = [
          {
              "column": "stream_order_none",
              "operator": "in",
              "value": ['1','2','3','4']
              #"value": ['5','6','7','8']
          },
         # {
         #     "column": "month",
         #     "operator": "in",
         #     "value": ['5','6','7','8','9']
         # },
         # {
         #     "column": "river_forecast_center_none",
         #     "operator": "=",
         #     "value": "SERFC"
         # },
    ],
    include_geometry=True,
)
#display(gdf_filters.head())

# make a quick map of locations - see how it changes as you make different filter selections
basemap * gv.Points(gdf_filters, vdims=['kling_gupta_efficiency_mod2','configuration']).select(
    configuration='nwm30_retro').opts(
    color='kling_gupta_efficiency_mod2', 
    height=400, width=600, size=7, 
    cmap=cc.rainbow[::-1], colorbar=True, clim=(0,1))
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1102'>
#   <div id="d4a3e674-a178-4662-ab91-63a7927f1bcf" data-root-id="p1102" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"03d3c421-8856-4db9-8194-edcbac7f5c40":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1102"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1103","attributes":{"plot_id":"p1102","comm_id":"101be8f597d141dabaad7da9545b2094","client_comm_id":"0b12e9722b504ab2ba55e5d1b4f39198"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"03d3c421-8856-4db9-8194-edcbac7f5c40","roots":{"p1102":"d4a3e674-a178-4662-ab91-63a7927f1bcf"},"root_ids":["p1102"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# CPU times: user 1min 11s, sys: 552 ms, total: 1min 12s
# Wall time: 18.4 s
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Longitude,Latitude]   (kling_gupta_efficiency_mod2,configuration)

# %% [markdown]
# ### 4. More visualizations

# %%
# set up color and abbrevation settings to use across multiple plots

metric_abbrev=dict(
    kling_gupta_efficiency_mod2 = "KGE''",
    mean_absolute_relative_error = "MAE",
    pearson_correlation = "Corr",
    relative_bias  = "Rel.Bias",
    nash_sutcliffe_efficiency_normalized = "NNSE",
)
cmap_lin = cc.rainbow[::-1]
cmap_div = cc.CET_D1A[::-1]
metric_colors=dict(
    kling_gupta_efficiency_mod2          = {'cmap': cmap_lin, 'clim': (0,1)},  
    relative_bias                        = {'cmap': cmap_div, 'clim': (-1,1)},   
    pearson_correlation                  = {'cmap': cmap_lin, 'clim': (0,1)},     
    nash_sutcliffe_efficiency_normalized = {'cmap': cmap_lin, 'clim': (0,1)}, 
    mean_absolute_relative_error         = {'cmap': cmap_lin, 'clim': (0,2)},
)
metrics = list(metric_colors.keys())
configs = ['nwm30_retro']

# %% [markdown]
# #### 4a. Side by side metric maps
# First we will create side-by-side maps of the first query results above (all locations and configurations, no filters), showing metric values at each location, where dots are colored by metric value and sized by sample size.  See how the comparison changes for each metric.

# %%
# map_metric = 'kling_gupta_efficiency_mod2'
# map_metric = 'pearson_correlation'                  
# map_metric = 'nash_sutcliffe_efficiency_normalized'
# map_metric = 'mean_absolute_relative_error' 
map_metric = 'relative_bias'

# factor to size dots based on sample size 
size_factor = 15/max(gdf_filters[('primary_count')])

polys = gv.Points(
    gdf_all, 
    vdims = metrics + ['primary_location_id','configuration','primary_count'],
    label = 'metric value (color), sample size (size)',
).opts(
    height = 400,
    width = 600,
    line_color = 'gray',
    colorbar = True,
    size = hv.dim('primary_count') * 15/max(gdf_filters[('primary_count')]),
    tools = ['hover'],
    xaxis = 'bare',
    yaxis = 'bare',
    show_legend = True
)
maps = []
config = configs[0]
for map_metric in ['kling_gupta_efficiency_mod2','relative_bias']:
    maps.append(basemap * polys.select(configuration=config).opts(
            title=f"{config} | {metric_abbrev[map_metric]}",
            color = map_metric,
            clim = metric_colors[map_metric]['clim'],
            cmap = metric_colors[map_metric]['cmap']
        )
    )
maps[0] + maps[1]
# Out:
# :Layout
#    .Overlay.I  :Overlay
#       .Tiles.I                                                                                                                :Tiles   [x,y]
#       .Points.Metric_value_left_parenthesis_color_right_parenthesis_comma_sample_size_left_parenthesis_size_right_parenthesis :Points   [Longitude,Latitude]   (kling_gupta_efficiency_mod2,relative_bias,pearson_correlation,nash_sutcliffe_efficiency_normalized,mean_absolute_relative_error,primary_location_id,configuration,primary_count)
#    .Overlay.II :Overlay
#       .Tiles.I                                                                                                                :Tiles   [x,y]
#       .Points.Metric_value_left_parenthesis_color_right_parenthesis_comma_sample_size_left_parenthesis_size_right_parenthesis :Points   [Longitude,Latitude]   (kling_gupta_efficiency_mod2,relative_bias,pearson_correlation,nash_sutcliffe_efficiency_normalized,mean_absolute_relative_error,primary_location_id,configuration,primary_count)

# %% [markdown]
# #### 4b. Dataframe table and bar chart side by side
# Next we will summarize results across locations by creating a summary table with pandas (as we did above) and juxtapose it with a bar chart using holoviews and panel.

# %%
# Display dataframes and simple plots side by side using Panel
import panel as pn

gdf_summary = gdf_all.groupby('configuration').describe(percentiles=[.5]).unstack(1).reset_index().rename(
    columns={'level_0':'metric','level_1':'summary'}).pivot(
    index=['metric','configuration'], values=0, columns='summary')

gdf_bars = gdf_summary.drop('primary_count', axis=0)['50%'].reset_index().replace({'metric':metric_abbrev})
bars = hv.Bars(gdf_bars, kdims=['metric', 'configuration']).opts(
    xrotation=90, height=400, width=300, ylabel='median',xlabel='')

pn.Row(pn.pane.DataFrame(gdf_summary, width=800), bars)
# Out:
# Row
#     [0] DataFrame(DataFrame, width=800)
#     [1] HoloViews(Bars, height=400, sizing_mode='fixed', width=300)

# %% [markdown]
# #### 4c. Box-whisker plots of results by metric and model
#
# Next we'll create box-whisker plots to see the distribution of metrics across locations for each metric and configuration.

# %%
# remove geometry so holoviews knows this is not a map.
df = gdf_all.drop('geometry', axis=1)

opts = dict(
    show_legend=False, 
    width=100, 
    cmap='Set1', 
    xrotation=45,
    labelled=[]
)
boxplots = []
for metric in metrics:
    boxplots.append(
        hv.BoxWhisker(df, 'configuration', metric, label=metric_abbrev[metric]).opts(
            **opts,
            box_fill_color=hv.dim('configuration')
        )
    )
hv.Layout(boxplots).cols(len(metrics))
# Out:
# :Layout
#    .BoxWhisker.KGE_apostrophe_apostrophe :BoxWhisker   [configuration]   (kling_gupta_efficiency_mod2)
#    .BoxWhisker.Rel_full_stop_Bias        :BoxWhisker   [configuration]   (relative_bias)
#    .BoxWhisker.Corr                      :BoxWhisker   [configuration]   (pearson_correlation)
#    .BoxWhisker.NNSE                      :BoxWhisker   [configuration]   (nash_sutcliffe_efficiency_normalized)
#    .BoxWhisker.MAE                       :BoxWhisker   [configuration]   (mean_absolute_relative_error)

# %% [markdown]
# #### 4d. Histograms by metric and model
# Every good scientist loves a histogram.  The below example creates a layout of histograms by configuration and metric, which gives us a more complete understanding of the metric distributions.

# %%
import hvplot.pandas
histograms =[]
for metric in metrics:
    histograms.append(
        df[df['configuration']==config].hvplot.hist(
            y=metric, 
            ylim=(0,200),
            bin_range=metric_colors[metric]['clim'], 
            xlabel=metric_abbrev[metric],
        ).opts(height = 200, width=250, title = config)
    )
hv.Layout(histograms).cols(len(metrics))
# Out:
# :Layout
#    .Histogram.I   :Histogram   [kling_gupta_efficiency_mod2]   (kling_gupta_efficiency_mod2_count)
#    .Histogram.II  :Histogram   [relative_bias]   (relative_bias_count)
#    .Histogram.III :Histogram   [pearson_correlation]   (pearson_correlation_count)
#    .Histogram.IV  :Histogram   [nash_sutcliffe_efficiency_normalized]   (nash_sutcliffe_efficiency_normalized_count)
#    .Histogram.V   :Histogram   [mean_absolute_relative_error]   (mean_absolute_relative_error_count)

# %% [markdown]
# #### 4e. CDFs overlays by metric
# Every good scientist loves a CDF even more.  The below example creates a layout of histograms by configuration and metric, which gives us a more complete understanding of the metric distributions.  We include metrics here with (mostly) the same range (0,1) and 'good' value (1).
#
# Not interesting with 1 model scenario

# %%
import numpy as np

layout = []
for metric in [
    'kling_gupta_efficiency_mod2',
    'pearson_correlation',                  
    'nash_sutcliffe_efficiency_normalized',
]:
    xlim = metric_colors[metric]['clim']
    xlabel = metric_abbrev[metric]
    
    cdfs = hv.Curve([])
    for config in ['nwm30_retro']:
        data = df[df['configuration']==config]
        data[xlabel] = np.sort(data[metric])
        n = len(data[xlabel])
        data['y'] = 1. * np.arange(n) / (n - 1)    
        cdfs = cdfs * hv.Curve(data, xlabel, 'y', label=config)
        
    layout.append(
        cdfs.opts(
            width = 300,
            legend_position='top_left',
            xlim=xlim, 
            xlabel=xlabel,
            title=metric_abbrev[metric],
            shared_axes=False,
        )
    )
    
hv.Layout(layout).cols(5)
# Out:
# :Layout
#    .Overlay.I   :Overlay
#       .Curve.I           :Curve   [x]   (y)
#       .Curve.Nwm30_retro :Curve   [KGE'']   (y)
#    .Overlay.II  :Overlay
#       .Curve.I           :Curve   [x]   (y)
#       .Curve.Nwm30_retro :Curve   [Corr]   (y)
#    .Overlay.III :Overlay
#       .Curve.I           :Curve   [x]   (y)
#       .Curve.Nwm30_retro :Curve   [NNSE]   (y)

# %% [markdown]
# #### 4f. Bar charts by attribute
# In the third example query above, we demonstrate how to add attributes to the resulting dataframe for summary and visualization purposes.  In that example we generated a summary table to RFC region.  The below example uses those result to build bar charts of the median performance metric across locations within each RFC region.

# %%
df_bars = df_atts_summary.set_index('metric').drop('primary_count', axis=0).reset_index().set_index('summary').loc['50%']
df_bars = df_bars.replace({'metric': metric_abbrev}) \
    .rename(columns={'river_forecast_center_none':'rfc',0:'median'}) \
    .reset_index().drop('summary', axis=1)
df_bars.loc[df_bars['metric'] == 'MAE', 'median'] = 1 - df_bars.loc[df_bars['metric'] == 'MAE', 'median']
df_bars = df_bars.replace('MAE','1-MAE')

bars = hv.Bars(df_bars, kdims=['metric','configuration','rfc'], vdims=['median']).opts(
    xrotation=90, height=300, width=200, ylabel='median',xlabel='')

layout = []
for rfc in df_bars['rfc'].unique():
    layout.append(bars.select(rfc=rfc).opts(title=rfc))
hv.Layout(layout).cols(6)
# Out:
# :Layout
#    .Bars.I    :Bars   [metric,configuration,rfc]   (median)
#    .Bars.II   :Bars   [metric,configuration,rfc]   (median)
#    .Bars.III  :Bars   [metric,configuration,rfc]   (median)
#    .Bars.IV   :Bars   [metric,configuration,rfc]   (median)
#    .Bars.V    :Bars   [metric,configuration,rfc]   (median)
#    .Bars.VI   :Bars   [metric,configuration,rfc]   (median)
#    .Bars.VII  :Bars   [metric,configuration,rfc]   (median)
#    .Bars.VIII :Bars   [metric,configuration,rfc]   (median)
#    .Bars.IX   :Bars   [metric,configuration,rfc]   (median)
#    .Bars.X    :Bars   [metric,configuration,rfc]   (median)
#    .Bars.XI   :Bars   [metric,configuration,rfc]   (median)
#    .Bars.XII  :Bars   [metric,configuration,rfc]   (median)

# %% [markdown]
# #### 4g Scatter plots by attribute
#
# Scatter plots of location metric values and location characteristics can provide insight about the relationship between the two - i.e., does model performance have a clear relationship with any of the characteristics?
#
# First review the attributes added to the (3rd) query above to see what the options are (or run a new query to add others).
# Let's create scatter plots of

# %%
# As examples, let's create scatter plots of KGE with each of the numeric attributes

import pandas as pd
import numpy as np

import geoviews as gv
import holoviews as hv
import colorcet as cc
hv.extension('bokeh', logo=False)
gv.extension('bokeh', logo=False)
basemap = hv.element.tiles.CartoLight()

location_chars = [
    'aridity',
    'runoff_ratio',
    'baseflow_index',
    'stream_order',  
    'q_mean_cms',
    'slope_fdc',  
    'frac_urban',
    'frac_snow',
    'forest_frac'
]
df_atts.columns = df_atts.columns.str.replace('_none', '')
df_atts[location_chars] = df_atts[location_chars].apply(pd.to_numeric)
df_atts['config_num'] = np.where(df_atts['configuration']=='nwm30_retro',1,2)

metrics = [
    'kling_gupta_efficiency_mod2',
    'pearson_correlation',                  
    'mean_absolute_relative_error',
    'relative_bias',
]
from bokeh.models import FixedTicker

scatter_layout = []
for char in location_chars:
    scatter_layout.append(
        hv.Scatter(
            df_atts, 
            kdims=[char],
            vdims=['kling_gupta_efficiency_mod2', 'relative_bias', 'primary_location_id','config_num'],
            label="nwm3.0"
        ).opts(
            width = 400, height = 300,
            #color = 'relative_bias',
            #color = 'config_num',
            #cmap = ['#377EB8', '#E41A1C'],
            #colorbar = True,
            clim=(0.5,2.5),
            ylabel = "KGE''",
            tools=['hover'],
            ylim=(-1,1),
            size=4,
            alpha=0.8,
            show_legend = True,
            # colorbar_opts={
            #     'ticker': FixedTicker(ticks=[1,2]),
            #     'major_label_overrides': {
            #         1: 'nwm30_retro',  
            #     },
            #     'major_label_text_align': 'left',
            # },
        ))
hv.Layout(scatter_layout).opts(show_legends = True).cols(3)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p5740'>
#   <div id="ccd94032-8b66-4b49-a76f-cfca09ffcf4c" data-root-id="p5740" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"b89c883c-c11c-4b3f-9387-4168d9da72ac":{"version":"3.3.4","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p5740"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p5741","attributes":{"plot_id":"p5740","comm_id":"ca0bbb03065847e0886b1b09142e83f9","client_comm_id":"042fe689b2634e3dab7b85be841445be"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"Any","default":"none"},{"name":"value","kind":"Any","default":null}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}]}};
#   var render_items = [{"docid":"b89c883c-c11c-4b3f-9387-4168d9da72ac","roots":{"p5740":"ccd94032-8b66-4b49-a76f-cfca09ffcf4c"},"root_ids":["p5740"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# :Layout
#    .Scatter.Nwm3_full_stop_0.I    :Scatter   [aridity]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.II   :Scatter   [runoff_ratio]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.III  :Scatter   [baseflow_index]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.IV   :Scatter   [stream_order]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.V    :Scatter   [q_mean_cms]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.VI   :Scatter   [slope_fdc]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.VII  :Scatter   [frac_urban]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.VIII :Scatter   [frac_snow]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
#    .Scatter.Nwm3_full_stop_0.IX   :Scatter   [forest_frac]   (kling_gupta_efficiency_mod2,relative_bias,primary_location_id,config_num)
